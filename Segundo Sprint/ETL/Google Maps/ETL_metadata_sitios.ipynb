# %% [markdown]
# ----
# **ETL METADATA-SITIOS:**
# ---
# ----

# %%
# Importacion de librerias a utilizar
from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
import pyarrow.parquet as pq

# %%
# Establece conexión con google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def aplicar_ETL():
  # Variables donde se almacenan las rutas de los archivos crudos
  metadata_9 ='/content/drive/MyDrive/Darío Aveiro/PF Darío Aveiro/Google Maps/metadata-sitios/9.json'
  metadata_11 ='/content/drive/MyDrive/Darío Aveiro/PF Darío Aveiro/Google Maps/metadata-sitios/11.json'
  metadata_10 ='/content/drive/MyDrive/Darío Aveiro/PF Darío Aveiro/Google Maps/metadata-sitios/10.json'
  metadata_6 ='/content/drive/MyDrive/Darío Aveiro/PF Darío Aveiro/Google Maps/metadata-sitios/6.json'


  # Desarrollo de ETL---------------------------------

  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_9=pd.read_json(metadata_9)
    metadata_9=metadata_9.iloc[:,:14]
    # Eliminación de columna importantes
    df_metadata_9=metadata_9.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Elimina valores nulos
    df_metadata_9=df_metadata_9.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_9['latitude']=df_metadata_9['latitude'].astype('float')
    df_metadata_9['longitude']=df_metadata_9['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_9=df_metadata_9[df_metadata_9['num_of_reviews']>20].reset_index(drop=True)
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Seafood","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    filtro_gastronomico=df_metadata_9['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_9=df_metadata_9[filtro_gastronomico].reset_index(drop=True)
    # Exportar archivo en formato parquet
    df_metadata_9.to_parquet('df_metadata_9_procesado.parquet')
  except: pass


  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_11=pd.read_json(metadata_11)
    metadata_11=metadata_11.iloc[:,:14]
    # Eliminación de columna importantes
    df_metadata_11=metadata_11.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Elimina valores nulos
    df_metadata_11=df_metadata_11.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_11['latitude']=df_metadata_11['latitude'].astype('float')
    df_metadata_11['longitude']=df_metadata_11['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_11=df_metadata_11[df_metadata_11['num_of_reviews']>20].reset_index(drop=True)
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Cajun restaurant","Steak house, Fine dining restaurant, Seafood","Steak house", "Seafood","Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    filtro_gastronomico=df_metadata_11['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_11=df_metadata_11[filtro_gastronomico].reset_index(drop=True)
    # Exportar archivo en formato parquet
    df_metadata_11.to_parquet('df_metadata_11_procesado.parquet')
  except: pass


  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_10=pd.read_json(metadata_10)
    metadata_10=metadata_10.iloc[:,:14]
    # Eliminación de columna importantes
    df_metadata_10=metadata_10.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Elimina valores nulos
    df_metadata_10=df_metadata_10.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_10['latitude']=df_metadata_10['latitude'].astype('float')
    df_metadata_10['longitude']=df_metadata_10['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_10=df_metadata_10[df_metadata_10['num_of_reviews']>20].reset_index(drop=True)
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Restaurant, Bar, Eastern European restaurant","Bar & grill","Wine bar, Delivery service, Fine dining restaurant","Cajun restaurant","Steak house, Fine dining restaurant, Seafood","Steak house", "Seafood","Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    filtro_gastronomico=df_metadata_10['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_10=df_metadata_10[filtro_gastronomico].reset_index(drop=True)
    # Exportar archivo en formato parquet
    df_metadata_10.to_parquet('df_metadata_10_procesado.parquet')
  except: pass


  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_6=pd.read_json(metadata_6)
    metadata_6=metadata_6.iloc[:,:14]
    # Eliminación de columna importantes
    df_metadata_6=metadata_6.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Elimina valores nulos
    df_metadata_6=df_metadata_6.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_6['latitude']=df_metadata_6['latitude'].astype('float')
    df_metadata_6['longitude']=df_metadata_6['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_6=df_metadata_6[df_metadata_6['num_of_reviews']>20].reset_index(drop=True)
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Cafe","Restaurant, Bar, Eastern European restaurant","Bar & grill","Wine bar, Delivery service, Fine dining restaurant","Cajun restaurant","Steak house, Fine dining restaurant, Seafood","Steak house", "Seafood","Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    filtro_gastronomico=df_metadata_6['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_6=df_metadata_6[filtro_gastronomico].reset_index(drop=True)
    # Exportar archivo en formato parquet
    df_metadata_6.to_parquet('df_metadata_6_procesado.parquet')
  except:pass


  # # Muestra datasets ya procesados
  print('\n---------------------------------------------------------------------Dataset "df_metadata_9" procesado-------------------------------------------------------\n')
  display(df_metadata_9)
  print('\n---------------------------------------------------------------------Dataset "df_metadata_11" procesado--------------------------------------------------------\n')
  display(df_metadata_11)
  print('\n---------------------------------------------------------------------Dataset "df_metadata_10" procesado----------------------------------------------------------\n')
  display(df_metadata_10)
  print('\n---------------------------------------------------------------------Dataset "metadata_6" procesado----------------------------------------------------------\n')
  display(df_metadata_6)

# %%
# NO BORRAR ---- TIENE MODIFICACIONES IMPORTANTES (POST REUNION)adaptacion de Pablo
def aplicar_ETL():
  # Variables donde se almacenan las rutas de los archivos crudos
  metadata_9 ='/content/drive/MyDrive/Proyecto Final/Google Maps/metadata-sitios/9.json'
  metadata_11 ='/content/drive/MyDrive/Proyecto Final/Google Maps/metadata-sitios/11.json'
  metadata_10 ='/content/drive/MyDrive/Proyecto Final/Google Maps/metadata-sitios/10.json'
  metadata_6 ='/content/drive/MyDrive/Proyecto Final/Google Maps/metadata-sitios/6.json'


  # Desarrollo de ETL---------------------------------

  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_9=pd.read_json(metadata_9,lines=True)
    # Eliminación de columna importantes
    df_metadata_9=metadata_9.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Lista de estados (utilizando regex)
    lista_estados= [
        "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
        "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
        "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
        "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
        "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
    ]
    regex = '|'.join(lista_estados)
    # Crear columna estados a partir de columna "address"
    df_metadata_9['state']=metadata_9['address'].str.extract(r'.*?(\b(?:{})\b).*'.format(regex))
    # Filtrar por los estados seleccionados
    estados=['PA','FL','CA','IL']
    df_metadata_9=df_metadata_9[df_metadata_9['state'].isin(estados)].reset_index(drop=True)
    # Elimina valores nulos
    df_metadata_9=df_metadata_9.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_9['latitude']=df_metadata_9['latitude'].astype('float')
    df_metadata_9['longitude']=df_metadata_9['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_9=df_metadata_9[df_metadata_9['num_of_reviews']>20].reset_index(drop=True)
    # Adaptar a formato string la columna "category"
    df_metadata_9['category']=df_metadata_9['category'].apply(str).str.strip('[').str.strip(']')
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Seafood","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    # Transformar columna "category" en string
    filtro_gastronomico=df_metadata_9['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_9=df_metadata_9[filtro_gastronomico].reset_index(drop=True)

    # Exportar archivo en formato parquet
    df_metadata_9.to_parquet('df_metadata_10_procesado.parquet')
  except: pass


  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_11=pd.read_json(metadata_11,lines=True)
    # Eliminación de columna importantes
    df_metadata_11=metadata_11.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Lista de estados (utilizando regex)
    lista_estados= [
        "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
        "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
        "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
        "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
        "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
    ]
    regex = '|'.join(lista_estados)
    # Crear columna estados a partir de columna "address"
    df_metadata_11['state']=metadata_11['address'].str.extract(r'.*?(\b(?:{})\b).*'.format(regex))
    # Filtrar por los estados seleccionados
    estados=['PA','FL','CA','IL']
    df_metadata_11=df_metadata_11[df_metadata_10['state'].isin(estados)].reset_index(drop=True)
    # Elimina valores nulos
    df_metadata_11=df_metadata_11.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_11['latitude']=df_metadata_11['latitude'].astype('float')
    df_metadata_11['longitude']=df_metadata_11['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_11=df_metadata_11[df_metadata_11['num_of_reviews']>20].reset_index(drop=True)
    # Adaptar a formato string la columna "category"
    df_metadata_11['category']=df_metadata_11['category'].apply(str).str.strip('[').str.strip(']')
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Seafood","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    # Transformar columna "category" en string
    filtro_gastronomico=df_metadata_11['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_11=df_metadata_11[filtro_gastronomico].reset_index(drop=True) # linea con Error
    # Exportar archivo en formato parquet
    df_metadata_10.to_parquet('df_metadata_10_procesado.parquet')
  except: pass


  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_10=pd.read_json(metadata_10,lines=True)
    # Eliminación de columna importantes
    df_metadata_10=metadata_10.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Lista de estados (utilizando regex)
    lista_estados= [
        "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
        "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
        "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
        "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
        "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
    ]
    regex = '|'.join(lista_estados)
    # Crear columna estados a partir de columna "address"
    df_metadata_10['state']=metadata_10['address'].str.extract(r'.*?(\b(?:{})\b).*'.format(regex))
    # Filtrar por los estados seleccionados
    estados=['PA','FL','CA','IL']
    df_metadata_10=df_metadata_10[df_metadata_10['state'].isin(estados)].reset_index(drop=True)
    # Elimina valores nulos
    df_metadata_10=df_metadata_10.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_10['latitude']=df_metadata_10['latitude'].astype('float')
    df_metadata_10['longitude']=df_metadata_10['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_10=df_metadata_10[df_metadata_10['num_of_reviews']>20].reset_index(drop=True)
    # Adaptar a formato string la columna "category"
    df_metadata_10['category']=df_metadata_10['category'].apply(str).str.strip('[').str.strip(']')
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Seafood","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    # Transformar columna "category" en string
    filtro_gastronomico=df_metadata_10['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_10=df_metadata_10[filtro_gastronomico].reset_index(drop=True) # linea con Error
    # Exportar archivo en formato parquet
    df_metadata_10.to_parquet('df_metadata_10_procesado.parquet')
  except: pass


  try:
    #  Lee archivo y devuelve un dataframe de pandas
    metadata_6=pd.read_json(metadata_6,lines=True)
    # Eliminación de columna importantes
    df_metadata_6=metadata_6.drop(columns=['price', 'hours', 'MISC',	'state',	'relative_results', 'url'])
    # Lista de estados (utilizando regex)
    lista_estados= [
        "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
        "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
        "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
        "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
        "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
    ]
    regex = '|'.join(lista_estados)
    # Crear columna estados a partir de columna "address"
    df_metadata_6['state']=metadata_6['address'].str.extract(r'.*?(\b(?:{})\b).*'.format(regex))
    # Filtrar por los estados seleccionados
    estados=['PA','FL','CA','IL']
    df_metadata_6=df_metadata_6[df_metadata_6['state'].isin(estados)].reset_index(drop=True)
    # Elimina valores nulos
    df_metadata_6=df_metadata_6.dropna().reset_index(drop=True)
    # Cambio de Tipos
    df_metadata_6['latitude']=df_metadata_6['latitude'].astype('float')
    df_metadata_6['longitude']=df_metadata_6['longitude'].astype('float')

    # Trabajaremos con los negocios que contengan mas de 20 reseñas, ya que menos reseñas no seria eficiente para el sistema de recomendación
    df_metadata_6=df_metadata_6[df_metadata_6['num_of_reviews']>20].reset_index(drop=True)
    # Adaptar a formato string la columna "category"
    df_metadata_6['category']=df_metadata_6['category'].apply(str).str.strip('[').str.strip(']')
    # Filtrado de negocios por rubro gastronómico
    palabras_clave=["Restaurant","Hamburger restaurant","Restaurant, Bar","Bar","Restaurants","Food","Bubble Tea","Coffee & Tea","Bakery","Barbecue","Buffets","Burgers","Cafes","Catering","Cocktail Bars","Desserts","Diners","Food Trucks","Ice Cream & Frozen Yogurt","Juice Bars & Smoothies","Pizza","Seafood","Steakhouses","Sushi Bars","Tapas Bars","Wine Bars","Vegetarian","Vegan","Gluten-Free"]
    # Transformar columna "category" en string
    filtro_gastronomico=df_metadata_6['category'].str.contains('|'.join(palabras_clave),case=False)
    df_metadata_6=df_metadata_6[filtro_gastronomico].reset_index(drop=True)
    # Exportar archivo en formato parquet
    df_metadata_6.to_parquet('df_metadata_10_procesado.parquet')
  except:pass

  df_final=pd.concat([df_metadata_6,df_metadata_9,df_metadata_10,df_metadata_11]).reset_index(drop=True)
  # # Muestra datasets ya procesados
  print('\n---------------------------------------------------------------------Dataset "df_final" procesado-------------------------------------------------------\n')
  display(df_final)

  # print('\n---------------------------------------------------------------------Dataset "df_metadata_9" procesado-------------------------------------------------------\n')
  # display(df_metadata_9)
  # print('\n---------------------------------------------------------------------Dataset "df_metadata_11" procesado--------------------------------------------------------\n')
  # display(df_metadata_11)
  # print('\n---------------------------------------------------------------------Dataset "df_metadata_10" procesado----------------------------------------------------------\n')
  # display(df_metadata_10)
  # print('\n---------------------------------------------------------------------Dataset "metadata_6" procesado----------------------------------------------------------\n')
  # display(df_metadata_6)

# %%
aplicar_ETL()
# Out:
# ---------------------------------------------------------------------Dataset "df_final" procesado-------------------------------------------------------
#                                   name  \
# 0                       Ame Restaurant
# 1                   Flames Coffee Shop
# 2                         Jimmy John's
# 3                              Dunkin'
# 4                          Eko Kitchen
# ...                                ...
# 281282                        Steak 48
# 281283   Jack Mcnerney Chevrolet, Inc.
# 281284  Central Ny Spay Neuter Assista
# 281285                   Ok Feed Store
# 281286              Crestview Crossing
#
#                                                   address  \
# 0       Ame Restaurant, 689 Mission St, San Francisco,...
# 1       Flames Coffee Shop, 449 S Winchester Blvd, San...
# 2       Jimmy John's, 1431 N Kingsbury St, Chicago, IL...
# 3        Dunkin', 1745 N Sheffield Ave, Chicago, IL 60614
# ...
